# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\ANISH M S\\Downloads\\diabetes (1).csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
f1=df.groupby('Outcome').sum()

# %%
f1
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin      BMI  \
# Outcome
# 0               1649    54990          34092           9832    34396  15152.1
# 1               1304    37857          18981           5940    26890   9418.2
#
#          DiabetesPedigreeFunction    Age
# Outcome
# 0                         214.867  15595
# 1                         147.534   9934

# %%
df.Outcome.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
x=df.drop(['Outcome'],axis=1)
y=df.Outcome

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,stratify=y,random_state=10)

# %%
from sklearn.tree import DecisonTreeClassifier
from sklearn.preprocessing import cross_val_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 from sklearn.ensemble import BaggingClassifier
# ----> 2 bg_model=BaggingClassifier(base_estimator=DecisionTreeClassifier(),)
#
# NameError: name 'DecisionTreeClassifier' is not defined

# %%
from sklearn.ensemble import BaggingClassifier
bg_model=BaggingClassifier(base_estimator=DecisionTreeClassifier(),
                          n_estimator=100,
                          max_samples=0.8
                          oob_score=True
                          random_state=0)

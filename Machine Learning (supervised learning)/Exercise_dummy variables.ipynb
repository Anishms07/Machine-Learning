# %%
import pandas as pd
from tabulate import tabulate
import matplotlib.pyplot as plt

df=pd.read_csv("C:\\Users\\ANISH M S\\Downloads\\carprices.csv")
print(tabulate(df,headers="keys",tablefmt="grid"))
# Out:
# +----+-----------------------+-----------+-----------------+------------+
# |    | Car Model             |   Mileage |   Sell Price($) |   Age(yrs) |
# +====+=======================+===========+=================+============+
# |  0 | BMW X5                |     69000 |           18000 |          6 |
# +----+-----------------------+-----------+-----------------+------------+
# |  1 | BMW X5                |     35000 |           34000 |          3 |
# +----+-----------------------+-----------+-----------------+------------+
# |  2 | BMW X5                |     57000 |           26100 |          5 |
# +----+-----------------------+-----------+-----------------+------------+
# |  3 | BMW X5                |     22500 |           40000 |          2 |
# +----+-----------------------+-----------+-----------------+------------+
# |  4 | BMW X5                |     46000 |           31500 |          4 |
# +----+-----------------------+-----------+-----------------+------------+
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# Create a DataFrame with the provided data
data = {'Car Model': ['BMW X5', 'BMW X5', 'BMW X5', 'BMW X5', 'BMW X5', 'Audi A5', 'Audi A5', 'Audi A5', 'Audi A5', 'Mercedez Benz C class', 'Mercedez Benz C class', 'Mercedez Benz C class', 'Mercedez Benz C class'],
        'Mileage': [69000, 35000, 57000, 22500, 46000, 59000, 52000, 72000, 91000, 67000, 83000, 79000, 59000],
        'Sell Price($)': [18000, 34000, 26100, 40000, 31500, 29400, 32000, 19300, 12000, 22000, 20000, 21000, 33000],
        'Age(yrs)': [6, 3, 5, 2, 4, 5, 5, 6, 8, 6, 7, 7, 5]}

df = pd.DataFrame(data)

# Scatter plot of Mileage vs. Sell Price with regression line
plt.scatter(df['Mileage'], df['Sell Price($)'], label='Data')
reg_mileage = LinearRegression()
reg_mileage.fit(df[['Mileage']], df['Sell Price($)'])
plt.plot(df['Mileage'], reg_mileage.predict(df[['Mileage']]), color='red', label='Regression Line')
plt.xlabel('Mileage')
plt.ylabel('Sell Price($)')
plt.title('Scatter Plot: Mileage vs. Sell Price')
plt.legend()
plt.show()

# Scatter plot of Age vs. Sell Price with regression line
plt.scatter(df['Age(yrs)'], df['Sell Price($)'], label='Data')
reg_age = LinearRegression()
reg_age.fit(df[['Age(yrs)']], df['Sell Price($)'])
plt.plot(df['Age(yrs)'], reg_age.predict(df[['Age(yrs)']]), color='red', label='Regression Line')
plt.xlabel('Age(yrs)')
plt.ylabel('Sell Price($)')
plt.title('Scatter Plot: Age vs. Sell Price')
plt.legend()
plt.show()

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'],color="blue")
plt.plot()
